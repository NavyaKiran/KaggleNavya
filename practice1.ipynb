# %%
#Load the data
import pandas as pd 

file_path = '/kaggle/input/melbourne-housing-market/Melbourne_housing_FULL.csv'
home_data = pd.read_csv(file_path)
home_data.head(5)
# Out:
#        Suburb             Address  Rooms Type      Price Method SellerG  \
# 0  Abbotsford       68 Studley St      2    h        NaN     SS  Jellis
# 1  Abbotsford        85 Turner St      2    h  1480000.0      S  Biggin
# 2  Abbotsford     25 Bloomburg St      2    h  1035000.0      S  Biggin
# 3  Abbotsford  18/659 Victoria St      3    u        NaN     VB  Rounds
# 4  Abbotsford        5 Charles St      3    h  1465000.0     SP  Biggin
#
#         Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 0  3/09/2016       2.5    3067.0  ...       1.0  1.0     126.0           NaN
# 1  3/12/2016       2.5    3067.0  ...       1.0  1.0     202.0           NaN
# 2  4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 3  4/02/2016       2.5    3067.0  ...       2.0  1.0       0.0           NaN
# 4  4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
#
# ...

# %%
#Review the summary stats 
home_data.describe()
#Count is the number of non zero values in that column 
#mean is the average of values present 
#std is the standard deviation or the amount by which the values are spread out 
#min is the minimum value in that column 
#25% is the value present at the 25th percentile and same for 50 and 75 
#max is the maximum value in that column
# Out:
#               Rooms         Price      Distance      Postcode      Bedroom2  \
# count  34857.000000  2.724700e+04  34856.000000  34856.000000  26640.000000
# mean       3.031012  1.050173e+06     11.184929   3116.062859      3.084647
# std        0.969933  6.414671e+05      6.788892    109.023903      0.980690
# min        1.000000  8.500000e+04      0.000000   3000.000000      0.000000
# 25%        2.000000  6.350000e+05      6.400000   3051.000000      2.000000
# 50%        3.000000  8.700000e+05     10.300000   3103.000000      3.000000
# 75%        4.000000  1.295000e+06     14.000000   3156.000000      4.000000
# max       16.000000  1.120000e+07     48.100000   3978.000000     30.000000
#
#            Bathroom           Car       Landsize  BuildingArea     YearBuilt  \
# count  26631.000000  26129.000000   23047.000000   13742.00000  15551.000000
# mean       1.624798      1.728845     593.598993     160.25640   1965.289885
# ...

# %%
home_data.columns
#list out all the colums available in the dataset
# Out:
# Index(['Suburb', 'Address', 'Rooms', 'Type', 'Price', 'Method', 'SellerG',
#        'Date', 'Distance', 'Postcode', 'Bedroom2', 'Bathroom', 'Car',
#        'Landsize', 'BuildingArea', 'YearBuilt', 'CouncilArea', 'Lattitude',
#        'Longtitude', 'Regionname', 'Propertycount'],
#       dtype='object')

# %%
home_data = home_data.dropna(axis = 0)
home_data.head()
# Out:
#         Suburb          Address  Rooms Type      Price Method SellerG  \
# 2   Abbotsford  25 Bloomburg St      2    h  1035000.0      S  Biggin
# 4   Abbotsford     5 Charles St      3    h  1465000.0     SP  Biggin
# 6   Abbotsford      55a Park St      4    h  1600000.0     VB  Nelson
# 11  Abbotsford     124 Yarra St      3    h  1876000.0      S  Nelson
# 14  Abbotsford    98 Charles St      2    h  1636000.0      S  Nelson
#
#          Date  Distance  Postcode  ...  Bathroom  Car  Landsize  BuildingArea  \
# 2   4/02/2016       2.5    3067.0  ...       1.0  0.0     156.0          79.0
# 4   4/03/2017       2.5    3067.0  ...       2.0  0.0     134.0         150.0
# 6   4/06/2016       2.5    3067.0  ...       1.0  2.0     120.0         142.0
# 11  7/05/2016       2.5    3067.0  ...       2.0  0.0     245.0         210.0
# 14  8/10/2016       2.5    3067.0  ...       1.0  2.0     256.0         107.0
#
#     YearBuilt         CouncilArea Lattitude  Longtitude  \
# ...

# %%
home_data.isna().sum()
home_data.isnull().sum()
# Out:
# Suburb           0
# Address          0
# Rooms            0
# Type             0
# Price            0
# Method           0
# SellerG          0
# Date             0
# Distance         0
# Postcode         0
# Bedroom2         0
# Bathroom         0
# Car              0
# Landsize         0
# BuildingArea     0
# YearBuilt        0
# CouncilArea      0
# Lattitude        0
# Longtitude       0
# Regionname       0
# Propertycount    0
# dtype: int64

# %%
y = home_data.Price
y.head()
# Out:
# 2     1035000.0
# 4     1465000.0
# 6     1600000.0
# 11    1876000.0
# 14    1636000.0
# Name: Price, dtype: float64

# %%
features = ['Rooms', 'Bathroom', 'Landsize', 'Lattitude', 'Longtitude']
X = home_data[features]

# %%
from sklearn.tree import DecisionTreeRegressor

model = DecisionTreeRegressor(random_state=1)
model.fit(X, y)
# Out:
# DecisionTreeRegressor(random_state=1)

# %%
#Make predictions for 10 houses 
X_pred = X[:10]
print(X_pred)
# Out:
#     Rooms  Bathroom  Landsize  Lattitude  Longtitude
# 2       2       1.0     156.0   -37.8079    144.9934
# 4       3       2.0     134.0   -37.8093    144.9944
# 6       4       1.0     120.0   -37.8072    144.9941
# 11      3       2.0     245.0   -37.8024    144.9993
# 14      2       1.0     256.0   -37.8060    144.9954
# 18      2       1.0     220.0   -37.8010    144.9989
# 24      3       2.0     214.0   -37.8085    144.9964
# 25      2       2.0       0.0   -37.8078    144.9965
# 30      2       1.0     238.0   -37.8090    144.9976
# 32      3       2.0     113.0   -37.8056    144.9930

# %%
print(model.predict(X_pred))
# Out:
# [1035000. 1465000. 1600000. 1876000. 1636000. 1097000. 1350000.  750000.
#  1310000. 1200000.]
